# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/search/question-answering/abstractive-question-answering.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/search/question-answering/abstractive-question-answering.ipynb)
#
# # Abstractive Question Answering

# %% [markdown]
# Abstractive question-answering focuses on the generation of multi-sentence answers to open-ended questions. It usually works by searching massive document stores for relevant information and then using this information to synthetically generate answers. This notebook demonstrates how Pinecone helps you build an abstractive question-answering system. We need three main components:
#
# - A vector index to store and run semantic search
# - A retriever model for embedding context passages
# - A generator model to generate answers

# %% [markdown]
# # Install Dependencies

# %%
# !pip install -qU datasets pinecone-client sentence-transformers torch
# !pip install -qU datasets pinecone-client sentence-transformers torch
# !pip install PyPDF2
# !pip install fitz
# !pip install frontend
# !pip install tools
# !pip install --upgrade PyMuPDF
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 24.3 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Collecting configparser (from fitz)
#   Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.10/dist-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from fitz) (4.0.2)
# Collecting nipype (from fitz)
#   Downloading nipype-1.8.6-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fitz) (1.5.3)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from configobj->fitz) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2->fitz) (3.1.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (67.7.2)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (8.1.7)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.2)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 37.7 MB/s eta 0:00:00
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.0 MB/s eta 0:00:00
# Collecting traits!=5.0,<6.4,>=4.6 (from nipype->fitz)
#   Downloading traits-6.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 107.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.12.4)
# Collecting etelemetry>=0.2.0 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Collecting looseversion (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fitz) (2023.3.post1)
# Requirement already satisfied: future>=0.16 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (0.18.3)
# Requirement already satisfied: lxml>=4.3 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (4.9.3)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (2.31.0)
# Collecting ci-info>=0.2 (from etelemetry>=0.2.0->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2023.7.22)
# Installing collected packages: looseversion, traits, simplejson, isodate, configparser, configobj, ci-info, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed ci-info-0.3.0 configobj-5.0.8 configparser-6.0.0 etelemetry-0.3.1 fitz-0.0.1.dev2 isodate-0.6.1 looseversion-1.3.0 nipype-1.8.6 prov-2.0.0 pyxnat-1.6 rdflib-7.0.0 simplejson-3.19.2 traits-6.3.2
# Collecting frontend
#   Downloading frontend-0.0.3-py3-none-any.whl (32 kB)
# Collecting starlette>=0.12.0 (from frontend)
#   Downloading starlette-0.31.1-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 3.2 MB/s eta 0:00:00
# Collecting uvicorn>=0.7.1 (from frontend)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from frontend) (2.1.2)
# Collecting aiofiles (from frontend)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette>=0.12.0->frontend) (3.7.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.7.1->frontend) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.7.1->frontend)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.7.1->frontend) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (1.1.3)
# Installing collected packages: h11, aiofiles, uvicorn, starlette, frontend
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# Successfully installed aiofiles-23.2.1 frontend-0.0.3 h11-0.14.0 starlette-0.31.1 uvicorn-0.23.2
# Collecting tools
#   Downloading tools-0.1.9.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytils (from tools)
#   Downloading pytils-0.4.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tools) (1.16.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from tools) (4.9.3)
# Building wheels for collected packages: tools, pytils
#   Building wheel for tools (setup.py) ... done
#   Created wheel for tools: filename=tools-0.1.9-py3-none-any.whl size=46731 sha256=259b7bf4866b56d54c3740884ad52cc7920e8b5598142c933feed7171d6d7805
#   Stored in directory: /root/.cache/pip/wheels/c0/d0/70/a33bd4bed2af4f7038b038c16faab552cd0e9d9f4125223a71
#   Building wheel for pytils (pyproject.toml) ... done
#   Created wheel for pytils: filename=pytils-0.4.1-py3-none-any.whl size=32538 sha256=17b08c39f3035d90f536cb6bda0d32a4db81ec18c1e889a3227c3ff2bf783d29
#   Stored in directory: /root/.cache/pip/wheels/5a/eb/7c/3b6f0c25815749883152b2caca34c35dbaab13ec2864270cbd
# Successfully built tools pytils
# Installing collected packages: pytils, tools
# Successfully installed pytils-0.4.1 tools-0.1.9
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.23.5-cp310-none-manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 38.8 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.23.5 (from PyMuPDF)
#   Downloading PyMuPDFb-1.23.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 53.2 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.23.5 PyMuPDFb-1.23.5
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import os
import re
import string
import time
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
wn = WordNetLemmatizer()

# Check if the 'static/' directory exists, and create it if not
static_directory = 'static/'
if not os.path.exists(static_directory):
    os.makedirs(static_directory)


import fitz  # PyMuPDF
import pandas as pd

# Function to extract text from a PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    texts = []

    for page_number in range(len(doc)):
        page = doc[page_number]

        # Extract text from the page
        page_text = page.get_text()
        texts.append(page_text)

    return texts

# Provide a list of PDF file paths
#pdf_file_paths = ["file1.pdf", "file2.pdf", "file3.pdf","file4.pdf", "file6.pdf", "file7.pdf"]

pdf_file_paths = ["MeatLife2.pdf"]

# Create a list to store documents
docs = []

for pdf_file_path in pdf_file_paths:
    pdf_texts = extract_text_from_pdf(pdf_file_path)
    docs.append({"passage_text": pdf_texts})

# Create a pandas DataFrame with the documents
df1 = pd.DataFrame(docs)
df1['passage_text3'] = df1['passage_text'].apply(lambda x: ' '.join(x))

# df = df1
# df.head()


# def split_text_into_rows(text, max_length):
#     split_text = [text[i:i + max_length] for i in range(0, len(text), max_length)]
#     return split_text

# # Maximum character count for each row
# max_length = 100

# # Split the 'text' column into multiple rows
# df1['passage_text2'] = df1['passage_text'].apply(lambda x: split_text_into_rows(x, max_length))

# # Expand the list of split text into multiple rows
# df1 = df1.explode('passage_text2')

# # Reset the DataFrame index
# df1.reset_index(drop=True, inplace=True)
# df1.head()

delimiter = '.'
split_data = df1['passage_text3'].str.split(delimiter, expand=True)
split_data = split_data.stack().reset_index(level=1, drop=True)
split_data.name = 'passage_text2'
split_data
# Create a new DataFrame with the split data
df = pd.concat([df1, split_data], axis=1)
df['passage_text2'] = df['passage_text2'].replace('\n',' ', regex=True)

df.head()

# # Drop the original 'Text' column if it's no longer needed
# #df = df1.drop('passage_text2', axis=1)
# def clean_txt(text):
#    text = text.replace('\n', ' ')
#    text = text.replace("'", '')
#    #text = text.replace('.', '')
#    text = text.replace('"', '')
#    text = text.replace(',', '')
#    clean_text = [ wn.lemmatize(word, pos="v") for word in word_tokenize(text.lower())]
#    #clean_text2 = [word for word in clean_text if black_txt(word)]
#    return " ".join(clean_text)
#    #return text


# df['passage_text2'] = df['passage_text2'].apply(clean_txt)
# df.head()
# Out:
#                                         passage_text  \
# 0  [Advantages of Masan MEATLife \nafter restruct...
# 0  [Advantages of Masan MEATLife \nafter restruct...
# 0  [Advantages of Masan MEATLife \nafter restruct...
# 0  [Advantages of Masan MEATLife \nafter restruct...
# 0  [Advantages of Masan MEATLife \nafter restruct...
#
#                                        passage_text3  \
# 0  Advantages of Masan MEATLife \nafter restructu...
# 0  Advantages of Masan MEATLife \nafter restructu...
# 0  Advantages of Masan MEATLife \nafter restructu...
# 0  Advantages of Masan MEATLife \nafter restructu...
# 0  Advantages of Masan MEATLife \nafter restructu...
#
#                                        passage_text2
# 0  Advantages of Masan MEATLife  after restructur...
# 0   Accordingly, MML will be restructured to sepa...
# 0   The company will transform into  a business p...
# 0   Masan MEATLife (a member company of Masan Gro...
# 0   The company invested in the rest of the suppl...

# %%
df.drop(['passage_text','passage_text3'],axis=1,inplace=True)
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#                                        passage_text2
# 0  Advantages of Masan MEATLife  after restructur...
# 1   Accordingly, MML will be restructured to sepa...
# 2   The company will transform into  a business p...
# 3   Masan MEATLife (a member company of Masan Gro...
# 4   The company invested in the rest of the suppl...

# %%
# from transformers import AutoProcessor, Pix2StructForConditionalGeneration
# import requests
# from PIL import Image

# model = Pix2StructForConditionalGeneration.from_pretrained("google/deplot")
# processor = AutoProcessor.from_pretrained("google/deplot")
# url = "https://raw.githubusercontent.com/vis-nlp/ChartQA/main/ChartQA%20Dataset/val/png/5090.png"
# image = Image.open(requests.get(url, stream=True).raw)

# inputs = processor(images=image, text="Generate underlying data table of the figure below:", return_tensors="pt")
# predictions = model.generate(**inputs, max_new_tokens=512)
#print(processor.decode(predictions[0], skip_special_tokens=True))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.13G [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.62k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/851k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)solve/main/Arial.TTF:   0%|          | 0.00/276k [00:00<?, ?B/s]

# %%
new_row = processor.decode(predictions[0], skip_special_tokens=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-97201fde21a3> in <cell line: 1>()
# ----> 1 test = pd.DataFrame(new_row)
#       2 test
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     779         else:
#     780             if index is None or columns is None:
# --> 781                 raise ValueError("DataFrame constructor not properly called!")
#     782
#     783             index = ensure_index(index)
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.concat([df, new_row], axis=0)
df.tail(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-39c0ebea8b25> in <cell line: 1>()
# ----> 1 df = pd.concat([df, new_row], axis=0)
#       2 df.tail(1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     456                     "only Series and DataFrame objs are valid"
#     457                 )
# --> 458                 raise TypeError(msg)
#     459
#     460             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'str'>'; only Series and DataFrame objs are valid

# %%
df.tail(1)

# %% [markdown]
# # Initialize Pinecone Index

# %% [markdown]
# The Pinecone index stores vector representations of our historical passages which we can retrieve later using another vector (query vector). To build our vector index, we must first establish a connection with Pinecone. For this, we need an API from Pinecone. You can get one for free from [here](https://app.pinecone.io/), and after that, we initialize the connection as follows:

# %%
import pinecone

# connect to pinecone environment
pinecone.init(
    api_key="bb491778-4927-4fab-913d-18ca0578500a",
    environment="gcp-starter"  # find next to API key in console
)

# %% [markdown]
# Now we create a new index. We will name it "abstractive-question-answering" — you can name it anything we want. We specify the metric type as "cosine" and dimension as 768 because the retriever we use to generate context embeddings is optimized for cosine similarity and outputs 768-dimension vectors.

# %%
# Initialize Retriever

# %%
import torch
from sentence_transformers import SentenceTransformer

# set device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# load the retriever model from huggingface model hub
#retriever = SentenceTransformer("flax-sentence-embeddings/all_datasets_v3_mpnet-base", device=device)
retriever = SentenceTransformer("sentence-transformers/msmarco-roberta-base-v2", device=device)
#retriever = SentenceTransformer("sentence-transformers/multi-qa-MiniLM-L6-cos-v1", device=device)
#retriever = SentenceTransformer("sentence-transformers/multi-qa-mpnet-base-dot-v1", device=device)
#retriever = SentenceTransformer("sentence-transformers/all-distilroberta-v1", device=device)


retriever
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 250, 'do_lower_case': False}) with Transformer model: RobertaModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %%
import torch
from sentence_transformers import SentenceTransformer

# set device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
retriever = SentenceTransformer("sentence-transformers/msmarco-roberta-base-v2", device=device)



retriever

# %%
retriever.get_sentence_embedding_dimension()
# Out:
# 768

# %%
index_name = "abstractive-question-answering"

# check if the abstractive-question-answering index exists
if index_name not in pinecone.list_indexes():
    # create the index if it does not exist
    pinecone.create_index(
        index_name,
        dimension=retriever.get_sentence_embedding_dimension(),
        metric="cosine"
    )

# connect to abstractive-question-answering index we created
index = pinecone.Index(index_name)

# %% [markdown]
# Next, we need to initialize our retriever. The retriever will mainly do two things:
#
# - Generate embeddings for all historical passages (context vectors/embeddings)
# - Generate embeddings for our questions (query vector/embedding)
#
# The retriever will create embeddings such that the questions and passages that hold the answers to our queries are close to one another in the vector space. We will use a SentenceTransformer model based on Microsoft's MPNet as our retriever. This model performs quite well for comparing the similarity between queries and documents. We can use Cosine Similarity to compute the similarity between query and context vectors generated by this model (Pinecone automatically does this for us).

# %% [markdown]
# # Generate Embeddings and Upsert

# %%
from tqdm.auto import tqdm

batch_size = 64

for i in tqdm(range(0, len(df), batch_size)):
    # find end of batch
    i_end = min(i+batch_size, len(df))
    # extract batch
    batch = df.iloc[i:i_end]
    # generate embeddings for batch
    emb = retriever.encode(batch["passage_text2"].tolist()).tolist()
    # get metadata
    meta = batch.to_dict(orient="records")
    # create unique IDs
    ids = [f"{idx}" for idx in range(i, i_end)]
    # add all to upsert list
    to_upsert = list(zip(ids, emb, meta))
    # upsert/insert these records to pinecone
    _ = index.upsert(vectors=to_upsert)

# check that we have all vectors in index
index.describe_index_stats()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'dimension': 768,
#  'index_fullness': 0.03107,
#  'namespaces': {'': {'vector_count': 3107}},
#  'total_vector_count': 3107}

# %% [markdown]
# # Initialize Generator

# %% [markdown]
# We will use ELI5 BART for the generator which is a Sequence-To-Sequence model trained using the ‘Explain Like I’m 5’ (ELI5) dataset. Sequence-To-Sequence models can take a text sequence as input and produce a different text sequence as output.
#
# The input to the ELI5 BART model is a single string which is a concatenation of the query and the relevant documents providing the context for the answer. The documents are separated by a special token &lt;P>, so the input string will look as follows:
#
# >question: What is a sonic boom? context: &lt;P> A sonic boom is a sound associated with shock waves created when an object travels through the air faster than the speed of sound. &lt;P> Sonic booms generate enormous amounts of sound energy, sounding similar to an explosion or a thunderclap to the human ear. &lt;P> Sonic booms due to large supersonic aircraft can be particularly loud and startling, tend to awaken people, and may cause minor damage to some structures. This led to prohibition of routine supersonic flight overland.
#
# More detail on how the ELI5 dataset was built is available [here](https://arxiv.org/abs/1907.09190) and how ELI5 BART model was trained is available [here](https://yjernite.github.io/lfqa.html).
#
# Let's initialize the BART model using transformers.

# %%
from transformers import BartTokenizer, BartForConditionalGeneration
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import XLNetTokenizer, XLNetModel

load bart tokenizer and model from huggingface
tokenizer = BartTokenizer.from_pretrained('vblagoje/bart_lfqa')
generator = BartForConditionalGeneration.from_pretrained('vblagoje/bart_lfqa').to(device)

#tokenizer = T5Tokenizer.from_pretrained('google/flan-t5-xxl') #session crashed
#generator = T5ForConditionalGeneration.from_pretrained('google/flan-t5-xxl').to(device)



tokenizer = XLNetTokenizer.from_pretrained('xlnet-large-cased')
generator = XLNetModel.from_pretrained('xlnet-large-cased').to(device)

# %% [markdown]
# All the components of our abstract QA system are complete and ready to be queried. But first, let's write some helper functions to retrieve context passages from Pinecone index and to format the query in the way the generator expects the input.

# %%
def query_pinecone(query, top_k):
    # generate embeddings for the query
    xq = retriever.encode([query]).tolist()
    # search pinecone index for context passage with the answer
    xc = index.query(xq, top_k=top_k, include_metadata=True)
    return xc

# %%
def format_query(query, context):
    # extract passage_text from Pinecone search result and add the <P> tag
    context = [f"<P> {m['metadata']['passage_text2']}" for m in context]
    # concatinate all context passages
    context = " ".join(context)
    # contcatinate the query and context passages
    query = f"question: {query} context: {context}"
    return query

# %% [markdown]
# Let's test the helper functions. We will query the Pinecone index function we created earlier with the `query_pinecone` to get context passages and pass them to the `format_query` function.

# %%
query = "What is MeatDeli?"
result = query_pinecone(query, top_k=1)
result
# Out:
# {'matches': [{'id': '49',
#               'metadata': {'passage_text': ['Ideate, innovate, &\n'
#                                             'Increase mileage on your cloud i\n'
#                                             'Podcasts\n'
#                                             'YouTube\n'
#                                             'Need to know\n'
#                                             'Ad\n'
#                                             'Sign up for Tuoi Tre Sao\n'
#                                             'September 10, 2021 15:00 GMT+7\n'
#                                             'Advantages of Masan MEATLife '
#                                             'after\n'
#                                             'restructuring\n'
#                                             'On September 10, the Board of '
#                                             'Directors of Masan MEATLife Joint '
#                                             'Stock Company\n'
#                                             '(MML) sent a report to the '
#                                             'General Meeting of Shareholders '
#                                             "on the company's\n"
#                                             'restructuring plan.\n'
#                                             'Accordingly, MML will be '
#                                             'restructured to separate '
#                                             'independent business segments\n'
#                                             '(Feed - Farm - Food), including '
#                                             'the possibility of separating the '
#                                             'animal feed business.\n'
#                                             'The company will transform into a '
#                                             'business platform focused solely '
#                                             'on branded meat.\n'
#                                             'Masan MEATLife (a member company '
#                                             'of Masan Group) started in the '
#                                             'meat supply\n'
#                                             'chain by merging the two leading '
#                                             'animal feed companies in Vietnam, '
#                                             'ANCO and\n'
#                                             'Proconco, in 2015.\n'
#                                             'The company invested in the rest '
#                                             'of the supply chain (farms, '
#                                             'processing plants, retail\n'
#                                             'chains in 2017, 2018) and '
#                                             'completed the 3F chain with the '
#                                             'launch of clean meat\n'
#                                             'Price negotiable\n'
#                                             'Ho Chi Minh City\n'
#                                             '760 million VND\n'
#                                             'Binh Duong Province\n'
#                                             '1,080 billion VND\n'
#                                             'Binh Duong Province\n'
#                                             '0\n'
#                                             'Business\n'
#                                             'th\n'
#                                             'MEATDeli cooled meat is now '
#                                             'available at more than 2,300 '
#                                             'VinMart supermarkets and\n'
#                                             'VinMart+ stores\n'
#                                             'Ad\n'
#                                             'To land in Long Hoa\n'
#                                             'commune, Can Gio\n'
#                                             'district, 100% resident\n'
#                                             'coastal land\n'
#                                             'Stuck in business cap\n'
#                                             'to urgently upgrade\n'
#                                             '651m2. asphalt. Right\n'
#                                             'Binh Duong.\n'
#                                             'I need to sell a plot of\n'
#                                             'land of 210m2, fully\n'
#                                             'residential, 12m aspha\n'
#                                             'road\n'
#                                             'Only 1.6 billion (45%)\n'
#                                             'own land in An Lac\n'
#                                             'Ward, Binh Tan Distric\n'
#                                             'Buy Genuine Ink\n'
#                                             'by epsonshop.co.in/\n'
#                                             'Buy now\n'
#                                             '1:54\n'
#                                             '1:54\n'
#                                             '3\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'consumers MEATDeli. This is the '
#                                             'ﬁrst meat brand in Vietnam '
#                                             'produced using European\n'
#                                             'cooled meat processing '
#                                             'technology.\n'
#                                             'After nearly 3 years of market '
#                                             'launch, MEATDeli owns a '
#                                             'distribution system of more\n'
#                                             'than 2,700 points of sale in '
#                                             'Hanoi, Ho Chi Minh City and '
#                                             'surrounding areas with a\n'
#                                             'customer base of millions of '
#                                             'people.\n'
#                                             'Potential of meat segment\n'
#                                             'With a population of nearly 100 '
#                                             'million people, average income is '
#                                             'continuously\n'
#                                             'improving, causing the demand for '
#                                             'clean, traceable meat to increase '
#                                             'in Vietnam. The\n'
#                                             'pork market is worth more than 10 '
#                                             'billion USD and is the largest '
#                                             'segment in the F&B\n'
#                                             'industry.\n'
#                                             'However, this is an '
#                                             'unstandardized market as more '
#                                             'than 90% of pork products on the\n'
#                                             'market are unbranded. Meanwhile, '
#                                             'consumers are increasingly paying '
#                                             'attention to\n'
#                                             'products that can be traced back '
#                                             'to their origin. This creates '
#                                             "conditions for MML's clean\n"
#                                             'meat brand MEATDeli to have a lot '
#                                             'of potential for growth.\n'
#                                             'MML currently owns a high-tech '
#                                             'pig farm in Nghe An with a total '
#                                             'area of   over 223\n'
#                                             'hectares, investment capital of '
#                                             'up to 1,400 billion VND, capable '
#                                             'of providing 250,000\n'
#                                             'pigs per year. Here, from breeds '
#                                             'to food sources, experienced '
#                                             'experts closely monitor\n'
#                                             'the quality of each individual '
#                                             'pig.\n'
#                                             'Along with that, MML invested '
#                                             'more than 2,000 billion VND to '
#                                             'build two meat\n'
#                                             'processing complexes MEAT Ha Nam '
#                                             'and MEATDeli Saigon - where '
#                                             'MEATDeli cool\n'
#                                             'meat products and processed meat '
#                                             'products are processed.\n'
#                                             'The two complexes have a total '
#                                             'processing capacity of 2.8 '
#                                             'million ﬁsh/year. Healthy\n'
#                                             'pigs supplied to MEAT Ha Nam and '
#                                             'MEATDeli Saigon must undergo 3 '
#                                             'strict quarantine\n'
#                                             'levels. Up to now, MEAT Ha Nam '
#                                             'and MEATDeli Saigon are '
#                                             'considered the ﬁrst two\n'
#                                             'European standard cool meat '
#                                             'processing complexes in Vietnam.\n'
#                                             "MML's net revenue in the ﬁrst "
#                                             'half of 2021 reached 10,232 '
#                                             'billion VND, an increase of\n'
#                                             '42.1% compared to 7,202 billion '
#                                             'VND in the ﬁrst half of 2020. '
#                                             'Meat has become an\n'
#                                             'independent business segment with '
#                                             'a signiﬁcant scale of MML, '
#                                             'contributing 2,068\n'
#                                             'billion VND. billion VND in '
#                                             'revenue and 163 billion VND in '
#                                             'proﬁt before tax, interest and\n'
#                                             '3.6 billion VND\n'
#                                             'Ho Chi Minh City\n'
#                                             '990 million VND\n'
#                                             'Binh Duong Province\n'
#                                             '6 billion VND\n'
#                                             'Ho Chi Minh City\n'
#                                             "Masan MEATLife's pig farm\n"
#                                             'Selling 240m2 full\n'
#                                             'residential area, corne\n'
#                                             'of intersection, fronta\n'
#                                             'on DT750 Binh Duong\n'
#                                             'street\n'
#                                             'Cheap house for sale \n'
#                                             '1-slot alley near Go Va\n'
#                                             'market, Van Lang\n'
#                                             'University\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'depreciation (EBITDA), including '
#                                             '3F Viet, accounting for 20.5% of '
#                                             "the Company's total\n"
#                                             'revenue.\n'
#                                             'Masan MEATLife aims to bring the '
#                                             'meat business to a net proﬁt by '
#                                             'the end of this year\n'
#                                             'when the meat processing complex '
#                                             'reaches 25% - 30% of capacity '
#                                             'utilization expected\n'
#                                             'in the fourth quarter of 2021, '
#                                             'compared to current capacity '
#                                             'utilization. is nearly 11%.\n'
#                                             'Advantages of MML after '
#                                             'restructuring\n'
#                                             'According to the restructuring '
#                                             'plan, the Proconco business '
#                                             'division (and similarly Anco)\n'
#                                             'will be reorganized, and the '
#                                             'distribution system at ANCO and '
#                                             'Proconco will be\n'
#                                             'transferred to the factories. '
#                                             'This adjustment aims to simplify '
#                                             'the distribution system\n'
#                                             'and build strategic partnerships '
#                                             'suitable for the animal feed '
#                                             'business.\n'
#                                             'From there, complementing MML '
#                                             'improves productivity in the '
#                                             'animal feed and farm\n'
#                                             'sectors to convert into input for '
#                                             'MEATDeli meat. The ultimate goal '
#                                             'is to bring\n'
#                                             'Vietnamese consumers meat '
#                                             'products with traceable origin, '
#                                             'quality and reasonable\n'
#                                             'prices.\n'
#                                             'This internal restructuring of '
#                                             'MML does not change the '
#                                             'commercial conditions signed\n'
#                                             'with agents/distributors and does '
#                                             'not affect the rights of '
#                                             'employees, partners and\n'
#                                             'shareholders.\n'
#                                             'After restructuring, each '
#                                             'business segment will be '
#                                             'proactive and focus on doing its '
#                                             'role\n'
#                                             'well, MML focuses on developing '
#                                             'the meat segment. At the same '
#                                             'time, this change\n'
#                                             'Stork bran production line - '
#                                             'product of proconco company\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'does not affect the integrated 3F '
#                                             'model from farm to table that '
#                                             'Masan MEATLife owns.\n'
#                                             'In fact, Vietnamese consumers '
#                                             'tend to choose branded foods, '
#                                             'fresh and nutritious,\n'
#                                             'ensuring food hygiene and safety, '
#                                             'and originating from modern '
#                                             'shopping channels. This\n'
#                                             'is a trend that is accelerating '
#                                             'due to the impact of the COVID-19 '
#                                             'pandemic.\n'
#                                             'Integrating into the VinCommerce '
#                                             'retail chain (another Masan Group '
#                                             'Company) with\n'
#                                             'nearly 2,500 supermarkets and '
#                                             'VinMart/VinMart+ stores, MEATDeli '
#                                             'has a huge\n'
#                                             'advantage in distribution system, '
#                                             'best serving consumers. .\n'
#                                             'It can be seen that the '
#                                             'restructuring of MML is part of '
#                                             'the strategy announced by Mr.\n'
#                                             'Danny Le - General Director of '
#                                             'Masan Group at the 2021 General '
#                                             'Meeting of\n'
#                                             'Shareholders. Accordingly, Masan '
#                                             'is ready to cooperate with '
#                                             'potential strategic\n'
#                                             'partners. resources and '
#                                             'experience to maximize strengths '
#                                             'and realize the Point of Life\n'
#                                             'strategy to serve the essential '
#                                             'needs of consumers.\n'
#                                             'From the beginning of 2021 until '
#                                             'now, this group has continuously '
#                                             'cooperated with\n'
#                                             'many domestic and foreign '
#                                             'partners such as SK Group, a '
#                                             'group of investors including\n'
#                                             'Alibaba Group, Phuc Long tea and '
#                                             'coffee chain.\n'
#                                             'MEATDeli clean meat is processed '
#                                             'using European cool meat '
#                                             'technology\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'Bạn có biết\n'
#                                             'Cô gái liên tục đạp chân...\n'
#                                             'Nguy cơ rình rập trên\n'
#                                             'cao...\n'
#                                             'Giảm mức phí cấp giấy...\n'
#                                             'Khu nhà đất của Bệnh...\n'
#                                             'Từ chuyện Đất rừng\n'
#                                             'phương...\n'
#                                             'Lái ô tô ngược chiều...\n'
#                                             'Masan MEATLife\n'
#                                             ' Company restructuring\n'
#                                             ' animal feed business\n'
#                                             'clean meat MEATDeli\n'
#                                             ' VinMart/VinMart+\n'
#                                             'There are currently no comments. '
#                                             'Be the ﬁrst to comment\n'
#                                             'RELATED NEWS\n'
#                                             "Masan's Point of Life\n"
#                                             'strategy proves effective\n'
#                                             'VinMart+ doubles the\n'
#                                             'supply of MEATDeli clean\n'
#                                             'pork to serve consumers\n'
#                                             'in Ho Chi Minh City\n'
#                                             'VinMart\'s "Healthy during\n'
#                                             'the pandemic" insurance\n'
#                                             'package continues to\n'
#                                             'share diﬃculties with\n'
#                                             'customers\n'
#                                             'Thích\n'
#                                             'Chia sẻ\n'
#                                             'Comments ( 0 )\n'
#                                             'Leave your comment...\n'
#                                             ' \n'
#                                             'Most interested\n'
#                                             'Latest\n'
#                                             'Be the ﬁrst to give stars to this '
#                                             'article\n'
#                                             '0\n'
#                                             '0\n'
#                                             '0\n'
#                                             'Good essay? Giving stars to Tuoi '
#                                             'Tre\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'Biếm Họa\n'
#                                             'Do not miss\n'
#                                             'Vietnam had its ﬁrst\n'
#                                             'monkeypox-related death\n'
#                                             'in Ho Chi Minh City\n'
#                                             'Proposal to remove\n'
#                                             'ﬁngerprints and\n'
#                                             "hometown and use 'place\n"
#                                             "of residence' on citizen\n"
#                                             'identiﬁcation card\n'
#                                             'Israel demands the\n'
#                                             'resignation of the United\n'
#                                             'Nations secretary general\n'
#                                             "Has Israel's 'Iron Wall'\n"
#                                             'collapsed?\n'
#                                             'Arresting reporters to\n'
#                                             'steal money from people\n'
#                                             'in Dak Nong\n'
#                                             'Minister of Public\n'
#                                             "Security explains 'will\n"
#                                             'using a chip-embedded ID\n'
#                                             "card be tracked or not'?\n"
#                                             'News in the same category\n'
#                                             'EVN no longer has a\n'
#                                             'monopoly on power\n'
#                                             'sources\n'
#                                             'Businesses still have\n'
#                                             'diﬃculty converting to a\n'
#                                             'circular economy model\n'
#                                             'In 9 months, durian\n'
#                                             'exports brought in 1.63\n'
#                                             'billion USD\n'
#                                             'How are farmers who\n'
#                                             'suffer losses due to\n'
#                                             'African swine fever\n'
#                                             'supported?\n'
#                                             'The dangers are\n'
#                                             'unpredictable when\n'
#                                             'children use AI Chatbots\n'
#                                             "The 'big man' of fertilizers\n"
#                                             'is facing diﬃculties\n'
#                                             'because selling prices\n'
#                                             'have decreased, proﬁts\n'
#                                             'are mainly thanks to bank\n'
#                                             'deposits\n'
#                                             'Đọc thêm\n'
#                                             'Hung thần xa lộ: Một mình tung '
#                                             'hoành ngang\n'
#                                             'dọc trên quốc lộ\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'Nhiều xe khách hiện nay không '
#                                             'khác gì "hung thần xa \n'
#                                             'lộ". Một số nhà xe vi phạm tốc độ '
#                                             'mười mấy ngàn \n'
#                                             'lần/tháng khiến dư luận không '
#                                             'khỏi bàng hoàng.\n'
#                                             'Thời sự\n'
#                                             'Bức xúc trước tình trạng "đá '
#                                             'tặc" đào xới tan nát núi \n'
#                                             'Hòn Chà (TP Quy Nhơn, tỉnh Bình '
#                                             'Định), Chủ tịch \n'
#                                             'UBND tỉnh Bình Định Phạm Anh Tuấn '
#                                             'đòi truy trách …\n'
#                                             'Cần biết\n'
#                                             'Là một trong những công ty hàng '
#                                             'đầu về sức khỏe và \n'
#                                             'thể chất, với khoảng 700 sản phẩm '
#                                             'đang được lưu \n'
#                                             'hành trên toàn cầu, Herbalife đã '
#                                             'được người tiêu dùn…\n'
#                                             'Sức khỏe\n'
#                                             'Theo các chuyên gia, cúm có thể '
#                                             'gây tổn thương não, \n'
#                                             'viêm cơ tim ở trẻ nhỏ sau khi sốt '
#                                             'cao nên cần chủ \n'
#                                             'động tiêm vắc xin đầy đủ, nhận '
#                                             'diện đúng triệu chứn…\n'
#                                             'Giáo dục\n'
#                                             'Bộ Giáo dục và Đào tạo vừa có '
#                                             'hướng dẫn để gỡ khó \n'
#                                             'trong thực hiện các môn học tích '
#                                             'hợp và hoạt động \n'
#                                             'trải nghiệm. Hướng dẫn thực hiện '
#                                             'ưu tiên dạy theo …\n'
#                                             'Thời sự\n'
#                                             'Núi Cà Mon ở Quảng Ngãi nứt toác, '
#                                             'qua mỗi mùa \n'
#                                             'mưa, vết nứt dài, rộng và sâu hơn '
#                                             'khiến người dân \n'
#                                             'sống dưới chân núi thấp thỏm lo '
#                                             'sạt lở.\n'
#                                             'Lẩu thập cẩm\n'
#                                             "'Đúng kiểu 'chúng ta của sau "
#                                             "này'. Ai cũng thành... \n"
#                                             "người lạ trong mắt nhau thôi', "
#                                             'một người hài hước bình \n'
#                                             'luận.\n'
#                                             'Sức khỏe\n'
#                                             'Chủ tịch Bình Định truy trách '
#                                             'nhiệm các sở,\n'
#                                             "ngành để 'đá tặc' lộng hành\n"
#                                             'Herbalife được trao giải thưởng '
#                                             '‘Sản Phẩm\n'
#                                             'Vàng Vì Sức Khỏe Cộng Đồng năm '
#                                             '2023’\n'
#                                             'Phòng biến chứng tim và não do '
#                                             'cúm ở trẻ\n'
#                                             'em\n'
#                                             'Môn học tích hợp: Ưu tiên dạy '
#                                             'theo mạch\n'
#                                             'chương trình đã thiết kế\n'
#                                             'Núi nứt dài cả chục mét, sâu hơn '
#                                             '7m, dân lo\n'
#                                             'sạt lở\n'
#                                             "Ảnh vui 25-10: Cặp đôi hóa 'người "
#                                             "lạ' sau khi\n"
#                                             'có con\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'Sau khi hút 2 điếu thuốc lá mua '
#                                             'trên mạng, nam thanh \n'
#                                             'niên phải nhập viện trong tình '
#                                             'trạng nhịp tim chậm, \n'
#                                             'đau đầu, chóng mặt.\n'
#                                             'Kinh doanh\n'
#                                             '10 công ty chứng khoán dẫn đầu '
#                                             'nắm giữ 69,7% thị \n'
#                                             'phần môi giới cổ phiếu trên thị '
#                                             'trường, theo công bố \n'
#                                             'quý 3-2023 từ Sở Giao dịch chứng '
#                                             'khoán TP.HCM …\n'
#                                             'Biếm Họa\n'
#                                             'Việc dùng trợ giúp "gọi điện '
#                                             'thoại cho người thân" khi \n'
#                                             'vi phạm nồng độ cồn dường như '
#                                             'không có mấy tác \n'
#                                             'dụng.\n'
#                                             'Nhập viện vì hút 2 điếu thuốc lá '
#                                             'mua trên\n'
#                                             'mạng để tìm cảm giác lạ\n'
#                                             '10 công ty chứng khoán thị phần '
#                                             'khủng: Lớn\n'
#                                             'nhất đâu phải lãi nhất\n'
#                                             'Đo nồng độ cồn: Hồn ai nấy giữ!\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n',
#                                             'Chào Tháng 10 - Máy lọc\n'
#                                             'nước điện giải iON kiềm\n'
#                                             'ROBOT & EVERKING\n'
#                                             'chinh phục khách hàng\n'
#                                             '12.900.000 đ\n'
#                                             'Máy lọc nước ROBOT\n'
#                                             'trang bị màn hình an\n'
#                                             'toàn cho nguồn nước,\n'
#                                             'đạt Tiêu chuẩn Châu Âu\n'
#                                             'Chỉ 8.800đ/ngày sở hữu\n'
#                                             'ngay máy lọc nước\n'
#                                             'ROBOT ′thế hệ mới′, đạt\n'
#                                             'tiêu chuẩn CE\n'
#                                             'Ưu Đãi Tháng 10 - Máy\n'
#                                             'lọc nước điện giải iON\n'
#                                             'kiềm ROBOT xác lập Kỷ\n'
#                                             'Lục Thế Giới chỉ\n'
#                                             '16.500.000đ\n'
#                                             '5 trải nghiệm không nên\n'
#                                             'bỏ lỡ khi đến Hồ Mây\n'
#                                             'Park Vũng Tàu\n'
#                                             'Tết Trung thu tặng Yến\n'
#                                             'sào Vua Yến\n'
#                                             'Chương trình giảm giá\n'
#                                             'lõi lọc cho khách hàng\n'
#                                             'đang sử dụng máy lọc\n'
#                                             'nước A. O. Smith\n'
#                                             'Máy làm mát thế hệ mới,\n'
#                                             'giải pháp làm mát nhanh\n'
#                                             'thay thế điều hòa\n'
#                                             '2.500.000 đ\n'
#                                             'Máy lọc nước điện giải\n'
#                                             'EVERKING chỉ\n'
#                                             '9.900.000Đ - Đồng hành\n'
#                                             'hỗ trợ người bệnh\n'
#                                             'Yến sào từ Khánh Hòa\n'
#                                             'ưu đãi lên đến 50% dịp\n'
#                                             'Trung Thu\n'
#                                             '1.323.000 đ\n'
#                                             '46%\n'
#                                             'Cơ hội mua sắm\n'
#                                             'Cơ hội du lịch\n'
#                                             'Cơ hội học tập\n'
#                                             'Ξ\n'
#                                             'HOME\n'
#                                             'PAGE\n'
#                                             'VIDEO NEWS WORLD LAW BUSINESS '
#                                             'TECHNOLOGY CAR TOURISM LIFESTYLE\n'
#                                             'YOUNG\n'
#                                             'CULTURE ENTERTAINMENT SPORT '
#                                             'EDUCATION SCIENCE HEALTH REAL\n'
#                                             'FAKE\n'
#                                             'YOU\n'
#                                             'READ\n'
#                                             'Editor-in-Chief: Le The Chu\n'
#                                             'License to operate electronic '
#                                             'newspapers in\n'
#                                             'Vietnamese and English No. '
#                                             '561/GP-BTTTT, issued on\n'
#                                             'November 25, 2022.\n'
#                                             'Editorial information - Ho Chi '
#                                             'Minh City Youth Union\n'
#                                             'Address: 60A Hoang Van Thu, Ward '
#                                             '9, Phu Nhuan\n'
#                                             'District, City. Ho Chi Minh\n'
#                                             'Hotline: 0918.033.133 - Email: '
#                                             'tto@tuoitre.com.vn\n'
#                                             'Tuoi Tre Newspaper Advertising '
#                                             'Department:\n'
#                                             '028.39974848\n'
#                                             'Contact Advertising \n'
#                                             'Privacy Terms \n'
#                                             'Contact for\n'
#                                             'comments\n'
#                                             'Sign up for email - Open\n'
#                                             'the portal\n'
#                                             'To not miss news & events of\n'
#                                             'interest\n'
#                                             'Register here\n'
#                                             '© Copyright 2022 TuoiTre Online, '
#                                             'All rights reserved ® Tuoi Tre '
#                                             'Online holds the copyright to the '
#                                             'content on this website\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n'],
#                            'passage_text2': ' MEATDeli clean meat is processed '
#                                             'using European cool meat '
#                                             'technology VIDEO NEWS WORLD LAW '
#                                             'BUSINESS TECHNOLOGY CAR TOURISM '
#                                             'LIFESTYLE YOUNG CULTURE '
#                                             'ENTERTAINMENT SPORT EDUCATION '
#                                             'REAL ESTATE HEALTH REAL FAKE YO  '
#                                             'Bạn có biết Cô gái liên tục đạp '
#                                             'chân',
#                            'passage_text3': 'Ideate, innovate, &\n'
#                                             'Increase mileage on your cloud i\n'
#                                             'Podcasts\n'
#                                             'YouTube\n'
#                                             'Need to know\n'
#                                             'Ad\n'
#                                             'Sign up for Tuoi Tre Sao\n'
#                                             'September 10, 2021 15:00 GMT+7\n'
#                                             'Advantages of Masan MEATLife '
#                                             'after\n'
#                                             'restructuring\n'
#                                             'On September 10, the Board of '
#                                             'Directors of Masan MEATLife Joint '
#                                             'Stock Company\n'
#                                             '(MML) sent a report to the '
#                                             'General Meeting of Shareholders '
#                                             "on the company's\n"
#                                             'restructuring plan.\n'
#                                             'Accordingly, MML will be '
#                                             'restructured to separate '
#                                             'independent business segments\n'
#                                             '(Feed - Farm - Food), including '
# ...
#                                             'dọc trên quốc lộ\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n'
#                                             ' Nhiều xe khách hiện nay không '
#                                             'khác gì "hung thần xa \n'
#                                             'lộ". Một số nhà xe vi phạm tốc độ '
#                                             'mười mấy ngàn \n'
#                                             'lần/tháng khiến dư luận không '
#                                             'khỏi bàng hoàng.\n'
#                                             'Thời sự\n'
#                                             'Bức xúc trước tình trạng "đá '
#                                             'tặc" đào xới tan nát núi \n'
#                                             'Hòn Chà (TP Quy Nhơn, tỉnh Bình '
#                                             'Định), Chủ tịch \n'
#                                             'UBND tỉnh Bình Định Phạm Anh Tuấn '
#                                             'đòi truy trách …\n'
#                                             'Cần biết\n'
#                                             'Là một trong những công ty hàng '
#                                             'đầu về sức khỏe và \n'
#                                             'thể chất, với khoảng 700 sản phẩm '
#                                             'đang được lưu \n'
#                                             'hành trên toàn cầu, Herbalife đã '
#                                             'được người tiêu dùn…\n'
#                                             'Sức khỏe\n'
#                                             'Theo các chuyên gia, cúm có thể '
#                                             'gây tổn thương não, \n'
#                                             'viêm cơ tim ở trẻ nhỏ sau khi sốt '
#                                             'cao nên cần chủ \n'
#                                             'động tiêm vắc xin đầy đủ, nhận '
#                                             'diện đúng triệu chứn…\n'
#                                             'Giáo dục\n'
#                                             'Bộ Giáo dục và Đào tạo vừa có '
#                                             'hướng dẫn để gỡ khó \n'
#                                             'trong thực hiện các môn học tích '
#                                             'hợp và hoạt động \n'
#                                             'trải nghiệm. Hướng dẫn thực hiện '
#                                             'ưu tiên dạy theo …\n'
#                                             'Thời sự\n'
#                                             'Núi Cà Mon ở Quảng Ngãi nứt toác, '
#                                             'qua mỗi mùa \n'
#                                             'mưa, vết nứt dài, rộng và sâu hơn '
#                                             'khiến người dân \n'
#                                             'sống dưới chân núi thấp thỏm lo '
#                                             'sạt lở.\n'
#                                             'Lẩu thập cẩm\n'
#                                             "'Đúng kiểu 'chúng ta của sau "
#                                             "này'. Ai cũng thành... \n"
#                                             "người lạ trong mắt nhau thôi', "
#                                             'một người hài hước bình \n'
#                                             'luận.\n'
#                                             'Sức khỏe\n'
#                                             'Chủ tịch Bình Định truy trách '
#                                             'nhiệm các sở,\n'
#                                             "ngành để 'đá tặc' lộng hành\n"
#                                             'Herbalife được trao giải thưởng '
#                                             '‘Sản Phẩm\n'
#                                             'Vàng Vì Sức Khỏe Cộng Đồng năm '
#                                             '2023’\n'
#                                             'Phòng biến chứng tim và não do '
#                                             'cúm ở trẻ\n'
#                                             'em\n'
#                                             'Môn học tích hợp: Ưu tiên dạy '
#                                             'theo mạch\n'
#                                             'chương trình đã thiết kế\n'
#                                             'Núi nứt dài cả chục mét, sâu hơn '
#                                             '7m, dân lo\n'
#                                             'sạt lở\n'
#                                             "Ảnh vui 25-10: Cặp đôi hóa 'người "
#                                             "lạ' sau khi\n"
#                                             'có con\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n'
#                                             ' Sau khi hút 2 điếu thuốc lá mua '
#                                             'trên mạng, nam thanh \n'
#                                             'niên phải nhập viện trong tình '
#                                             'trạng nhịp tim chậm, \n'
#                                             'đau đầu, chóng mặt.\n'
#                                             'Kinh doanh\n'
#                                             '10 công ty chứng khoán dẫn đầu '
#                                             'nắm giữ 69,7% thị \n'
#                                             'phần môi giới cổ phiếu trên thị '
#                                             'trường, theo công bố \n'
#                                             'quý 3-2023 từ Sở Giao dịch chứng '
#                                             'khoán TP.HCM …\n'
#                                             'Biếm Họa\n'
#                                             'Việc dùng trợ giúp "gọi điện '
#                                             'thoại cho người thân" khi \n'
#                                             'vi phạm nồng độ cồn dường như '
#                                             'không có mấy tác \n'
#                                             'dụng.\n'
#                                             'Nhập viện vì hút 2 điếu thuốc lá '
#                                             'mua trên\n'
#                                             'mạng để tìm cảm giác lạ\n'
#                                             '10 công ty chứng khoán thị phần '
#                                             'khủng: Lớn\n'
#                                             'nhất đâu phải lãi nhất\n'
#                                             'Đo nồng độ cồn: Hồn ai nấy giữ!\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n'
#                                             ' Chào Tháng 10 - Máy lọc\n'
#                                             'nước điện giải iON kiềm\n'
#                                             'ROBOT & EVERKING\n'
#                                             'chinh phục khách hàng\n'
#                                             '12.900.000 đ\n'
#                                             'Máy lọc nước ROBOT\n'
#                                             'trang bị màn hình an\n'
#                                             'toàn cho nguồn nước,\n'
#                                             'đạt Tiêu chuẩn Châu Âu\n'
#                                             'Chỉ 8.800đ/ngày sở hữu\n'
#                                             'ngay máy lọc nước\n'
#                                             'ROBOT ′thế hệ mới′, đạt\n'
#                                             'tiêu chuẩn CE\n'
#                                             'Ưu Đãi Tháng 10 - Máy\n'
#                                             'lọc nước điện giải iON\n'
#                                             'kiềm ROBOT xác lập Kỷ\n'
#                                             'Lục Thế Giới chỉ\n'
#                                             '16.500.000đ\n'
#                                             '5 trải nghiệm không nên\n'
#                                             'bỏ lỡ khi đến Hồ Mây\n'
#                                             'Park Vũng Tàu\n'
#                                             'Tết Trung thu tặng Yến\n'
#                                             'sào Vua Yến\n'
#                                             'Chương trình giảm giá\n'
#                                             'lõi lọc cho khách hàng\n'
#                                             'đang sử dụng máy lọc\n'
#                                             'nước A. O. Smith\n'
#                                             'Máy làm mát thế hệ mới,\n'
#                                             'giải pháp làm mát nhanh\n'
#                                             'thay thế điều hòa\n'
#                                             '2.500.000 đ\n'
#                                             'Máy lọc nước điện giải\n'
#                                             'EVERKING chỉ\n'
#                                             '9.900.000Đ - Đồng hành\n'
#                                             'hỗ trợ người bệnh\n'
#                                             'Yến sào từ Khánh Hòa\n'
#                                             'ưu đãi lên đến 50% dịp\n'
#                                             'Trung Thu\n'
#                                             '1.323.000 đ\n'
#                                             '46%\n'
#                                             'Cơ hội mua sắm\n'
#                                             'Cơ hội du lịch\n'
#                                             'Cơ hội học tập\n'
#                                             'Ξ\n'
#                                             'HOME\n'
#                                             'PAGE\n'
#                                             'VIDEO NEWS WORLD LAW BUSINESS '
#                                             'TECHNOLOGY CAR TOURISM LIFESTYLE\n'
#                                             'YOUNG\n'
#                                             'CULTURE ENTERTAINMENT SPORT '
#                                             'EDUCATION SCIENCE HEALTH REAL\n'
#                                             'FAKE\n'
#                                             'YOU\n'
#                                             'READ\n'
#                                             'Editor-in-Chief: Le The Chu\n'
#                                             'License to operate electronic '
#                                             'newspapers in\n'
#                                             'Vietnamese and English No. '
#                                             '561/GP-BTTTT, issued on\n'
#                                             'November 25, 2022.\n'
#                                             'Editorial information - Ho Chi '
#                                             'Minh City Youth Union\n'
#                                             'Address: 60A Hoang Van Thu, Ward '
#                                             '9, Phu Nhuan\n'
#                                             'District, City. Ho Chi Minh\n'
#                                             'Hotline: 0918.033.133 - Email: '
#                                             'tto@tuoitre.com.vn\n'
#                                             'Tuoi Tre Newspaper Advertising '
#                                             'Department:\n'
#                                             '028.39974848\n'
#                                             'Contact Advertising \n'
#                                             'Privacy Terms \n'
#                                             'Contact for\n'
#                                             'comments\n'
#                                             'Sign up for email - Open\n'
#                                             'the portal\n'
#                                             'To not miss news & events of\n'
#                                             'interest\n'
#                                             'Register here\n'
#                                             '© Copyright 2022 TuoiTre Online, '
#                                             'All rights reserved ® Tuoi Tre '
#                                             'Online holds the copyright to the '
#                                             'content on this website\n'
#                                             'VIDEO\n'
#                                             'NEWS\n'
#                                             'WORLD\n'
#                                             'LAW\n'
#                                             'BUSINESS\n'
#                                             'TECHNOLOGY\n'
#                                             'CAR\n'
#                                             'TOURISM\n'
#                                             'LIFESTYLE YOUNG\n'
#                                             'CULTURE\n'
#                                             'ENTERTAINMENT\n'
#                                             'SPORT\n'
#                                             'EDUCATION\n'
#                                             'REAL ESTATE\n'
#                                             'HEALTH\n'
#                                             'REAL FAKE\n'
#                                             'YO\n'},
#               'score': 0.655517459,
#               'values': []}],
#  'namespace': ''}

# %%
from pprint import pprint

# %%
# format the query in the form generator expects the input
query = format_query(query, result["matches"])
pprint(query)
# Out:
# ('question: What is MeatDeli? context: <P>  MEATDeli clean meat is processed '
#  'using European cool meat technology VIDEO NEWS WORLD LAW BUSINESS TECHNOLOGY '
#  'CAR TOURISM LIFESTYLE YOUNG CULTURE ENTERTAINMENT SPORT EDUCATION REAL '
#  'ESTATE HEALTH REAL FAKE YO  Bạn có biết Cô gái liên tục đạp chân')

# %%
def generate_answer(query):
    # tokenize the query to get input_ids
    inputs = tokenizer([query], max_length=1024, return_tensors="pt").to(device)
    # use generator to predict output ids
    ids = generator.generate(inputs["input_ids"], num_beams=2, min_length=20, max_length=40)
    # use tokenizer to decode the output ids
    answer = tokenizer.batch_decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    return pprint(answer)

# %%
generate_answer(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5b490b2116b9> in <cell line: 1>()
# ----> 1 generate_answer(query)
#
# <ipython-input-22-1a72449f358f> in generate_answer(query)
#       3     inputs = tokenizer([query], max_length=1024, return_tensors="pt").to(device)
#       4     # use generator to predict output ids
# ----> 5     ids = generator.generate(inputs["input_ids"], num_beams=2, min_length=20, max_length=40)
#       6     # use tokenizer to decode the output ids
#       7     answer = tokenizer.batch_decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1406
#    1407         # 1. Handle `generation_config` and kwargs that might update it, and validate the `.generate()` call
# -> 1408         self._validate_model_class()
#    1409
#    1410         # priority: `generation_config` argument > `model.generation_config` (the default generation config)
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _validate_model_class(self)
#    1201             if generate_compatible_classes:
#    1202                 exception_message += f" Please use one of the following classes instead: {generate_compatible_classes}"
# -> 1203             raise TypeError(exception_message)
#    1204
#    1205     def _validate_model_kwargs(self, model_kwargs: Dict[str, Any]):
#
# TypeError: The current model class (XLNetModel) is not compatible with `.generate()`, as it doesn't have a language model head. Please use one of the following classes instead: {'XLNetLMHeadModel'}

# %% [markdown]
# As we can see, the generator used the provided context to answer our question. Let's run some more queries.

# %%
# query = "When was MeatDeli launched"
# context = query_pinecone(query, top_k=5)
# query = format_query(query, context["matches"])
# generate_answer(query)

# %% [markdown]
# To confirm that this answer is correct, we can check the contexts used to generate the answer.

# %%
# for doc in context["matches"]:
#     print(doc["metadata"]["passage_text2"], end='\n---\n')

# %% [markdown]
# In this case, the answer looks correct. If we ask a question and no relevant contexts are retrieved, the generator will typically return nonsensical or false answers, like with this question about COVID-19:

# %%
# query = "What is MeatDeli?"
# context = query_pinecone(query, top_k=10)
# query = format_query(query, context["matches"])
# generate_answer(query)

# %%
# for doc in context["matches"]:
#     print(doc["metadata"]["passage_text2"], end='\n---\n')

# %% [markdown]
# Let’s finish with a final few questions.

# %%
query = "When was meatdeli launched?"
context = query_pinecone(query, top_k=15)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('The first MEATDeli opened in Hanoi, Vietnam in 2015. The first MEATDeli was '
#  'opened in Hanoi, Vietnam in 2015. The first MEATDel')

# %%
context
# Out:
# {'matches': [{'id': '21',
#               'metadata': {'passage_text2': ' Meat has become an independent '
#                                             'business segment with  a '
#                                             'signiﬁcant scale of MML, '
#                                             'contributing 2,068 billion VND'},
#               'score': 0.49969846,
#               'values': []},
#              {'id': '7',
#               'metadata': {'passage_text2': ' Potential of meat segment With a '
#                                             'population of nearly 100 million '
#                                             'people, average income is  '
#                                             'continuously improving, causing '
#                                             'the demand for clean, traceable '
#                                             'meat  to increase in Vietnam'},
#               'score': 0.485234499,
#               'values': []},
#              {'id': '2',
#               'metadata': {'passage_text2': '\xa0The company will transform '
#                                             'into  a business platform focused '
#                                             'solely on branded meat'},
#               'score': 0.469359666,
#               'values': []}],
#  'namespace': ''}

# %%
query = "What is the most profitable/sold product of MeatDeli?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('MeatDeli has a lot of products that are profitable. The most profitable '
#  'product is the "Clean Meat" brand. It\'s a clean meat brand that is sold at '
#  'a lot of supermarkets')

# %%
query = "What does MeatDeli sell?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('MeatDeli is a company that sells clean meat. They sell it in a variety of '
#  'flavors and textures.')

# %%
query = "What type of meat MeatDeli sell?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('MeatDeli sells a variety of meats, but the most common type is "clean meat" '
#  'which is meat that has been processed using European cool meat technology.')

# %%
query = "Is MeatDeli profitable?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("It's not profitable, but it's profitable. The company is profitable because "
#  "it has a lot of cash. It's not profitable because it has a lot of debt. It's "
#  'profitable because')

# %%
query = "How much did MeatDeli revenue grow?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("I'm not sure if this is what you're looking for, but I can tell you that "
#  "it's not that much. The revenue of MEATDeli is about 1.5 billion")

# %%
query = "Where did MeatDeli invest?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('MeatDeli is a subsidiary of the Masan Group, which is a conglomerate. The '
#  'Masan Group owns a lot of businesses in Vietnam, including a lot of meat '
#  'processing and meat distribution')

# %%
query = "Give me some information about pork industry from meatdeli?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ('Pork comes from pigs that are raised for meat. Pigs are raised for meat '
#  'because they are easy to domesticate. Pigs are raised for meat because they '
#  'are easy to domesticate. Pigs')

# %%
query = "Give me a summary of MeatDeli's achievements , revenue growth and profit"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("MeatDeli is the first clean meat restaurant in the world. It's been around "
#  "for a few years now, but it's the first clean meat restaurant in the US. "
#  "It's been")

# %%
query = "Give me some Potential of meat segment"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("I'm not sure if this is a good question, but I'll give it a shot. The "
#  "potential of meat segment in Vietnam is very high, and it's not even close "
#  'to the')

# %%
query = "How much revenue did Meatdeli make?"
context = query_pinecone(query, top_k=5)
query = format_query(query, context["matches"])
generate_answer(query)
# Out:
# ("I'm not sure if this is what you're looking for, but here's a link to a "
#  "report on MEATDeli's revenue.")

# %%
context
# Out:
# {'matches': [{'id': '21',
#               'metadata': {'passage_text2': ' Meat has become an independent '
#                                             'business segment with  a '
#                                             'signiﬁcant scale of MML, '
#                                             'contributing 2,068 billion VND'},
#               'score': 0.49969846,
#               'values': []},
#              {'id': '7',
#               'metadata': {'passage_text2': ' Potential of meat segment With a '
#                                             'population of nearly 100 million '
#                                             'people, average income is  '
#                                             'continuously improving, causing '
#                                             'the demand for clean, traceable '
#                                             'meat  to increase in Vietnam'},
#               'score': 0.485234499,
#               'values': []},
#              {'id': '2',
#               'metadata': {'passage_text2': '\xa0The company will transform '
#                                             'into  a business platform focused '
#                                             'solely on branded meat'},
#               'score': 0.469359666,
#               'values': []}],
#  'namespace': ''}

# %% [markdown]
# As we can see, the model can generate some decent answers.

# %% [markdown]
# # Example Application

# %% [markdown]
# To try out an application like this one, see this [example application](https://huggingface.co/spaces/pinecone/abstractive-question-answering).
